# %%
from src.utils.visualization import plot_confusion_matrix, plot_accuracy_curve, plot_loss_curve

# %%
train_loss = [0.9, 0.7, 0.5, 0.3]
val_loss = [1.0, 0.8, 0.6, 0.4]
train_acc = [60, 70, 80, 90]
val_acc = [58, 68, 78, 88]
y_true = [0, 1, 2, 1, 0, 2]
y_pred = [0, 2, 1, 1, 0, 2]
class_names = ['cat', 'dog', 'bird']

# %%
import torch

# %%
loss_a = torch.randn(100)
loss_b = torch.randn(100)

plot_loss_curve(loss_a, loss_b)

# %%
plot_accuracy_curve(train_acc, val_acc)

# %%
plot_confusion_matrix(y_true, y_pred, class_names)
