# %%
from src.utils.metrics import accuracy

# %%
import torch

# %%
a = torch.randint(10, (10, 1))
b = torch.randint(10, (10,1))

# %%
a
# Out:
# tensor([[9],
#         [1],
#         [1],
#         [9],
#         [2],
#         [5],
#         [4],
#         [7],
#         [7],
#         [9]])

# %%
b
# Out:
# tensor([[5],
#         [7],
#         [9],
#         [5],
#         [9],
#         [6],
#         [2],
#         [4],
#         [8],
#         [9]])

# %%
corr = accuracy(a, b)
corr
# Out:
# 0.0

# %%
correct = (a == b).sum().item()
correct
# Out:
# 1

# %%
a ==b
# Out:
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [ True]])
