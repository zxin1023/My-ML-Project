# %%
import sys
sys.path.append('..')
from src.data_pipeline.preprocessing.preprocessing import preprocess_data

# %%
from src.data_pipeline.preprocessing.preprocessing import preprocess_data
