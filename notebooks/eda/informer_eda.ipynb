# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../../data/raw/ETTh1.csv')
df.head()
# Out:
#                   date   HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0  2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 1  2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2  2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 3  2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 4  2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
import os
import sys
sys.path.append('../../')

from src.data_pipeline.preprocessing.preprocessing import preprocess_data

# %%
preprocess_data('../../data/raw/ETTh1.csv')
# Out:
# d:\CODE\MY_CODE\My-ML-Project\notebooks\eda\../..\src\data_pipeline\preprocessing\preprocessing.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# d:\CODE\MY_CODE\My-ML-Project\notebooks\eda\../..\src\data_pipeline\preprocessing\preprocessing.py:28: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df = df.resample('1H').mean()
# d:\CODE\MY_CODE\My-ML-Project\notebooks\eda\../..\src\data_pipeline\preprocessing\preprocessing.py:30: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
